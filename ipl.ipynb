# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
ipl=pd.read_csv('matches.csv')

# %%
ipl
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5        6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7        8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8        9    2017           Pune  2017-04-11             Delhi Daredevils
# 9       10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10      11    2017        Kolkata  2017-04-13              Kings XI Punjab
# ...

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
ipl['player_of_match']
# Out:
# 0         Yuvraj Singh
# 1            SPD Smith
# 2              CA Lynn
# 3           GJ Maxwell
# 4            KM Jadhav
# 5          Rashid Khan
# 6               N Rana
# 7             AR Patel
# 8            SV Samson
# 9            JJ Bumrah
# 10           SP Narine
# 11          KA Pollard
# 12              AJ Tye
# 13          RV Uthappa
# 14         CJ Anderson
# 15              N Rana
# 16           BA Stokes
# 17     NM Coulter-Nile
# 18             B Kumar
# 19            CH Gayle
# 20       KS Williamson
# 21          JC Buttler
# 22            SK Raina
# 23      MJ McClenaghan
# 24            MS Dhoni
# 25             HM Amla
# 26     NM Coulter-Nile
# 27           BA Stokes
# 28          RV Uthappa
# 29              AJ Tye
#             ...
# 726         SL Malinga
# 727           R Ashwin
# 728          DA Warner
# 729          HH Pandya
# 730            V Kohli
# 731          SPD Smith
# 732            SS Iyer
# 733            K Ahmed
# 734           PA Patel
# ...

# %%
#which stadium is best for winning by run

# %%
ipl[['win_by_runs','venue']]
# Out:
#      win_by_runs                                      venue
# 0             35  Rajiv Gandhi International Stadium, Uppal
# 1              0    Maharashtra Cricket Association Stadium
# 2              0     Saurashtra Cricket Association Stadium
# 3              0                     Holkar Cricket Stadium
# 4             15                      M Chinnaswamy Stadium
# 5              0  Rajiv Gandhi International Stadium, Uppal
# 6              0                           Wankhede Stadium
# 7              0                     Holkar Cricket Stadium
# 8             97    Maharashtra Cricket Association Stadium
# 9              0                           Wankhede Stadium
# 10             0                               Eden Gardens
# 11             0                      M Chinnaswamy Stadium
# 12             0     Saurashtra Cricket Association Stadium
# 13            17                               Eden Gardens
# 14            51                           Feroz Shah Kotla
# ...

# %%
ipl[ipl['win_by_runs']>0]['venue'].mode()
# Out:
# 0    Wankhede Stadium
# dtype: object

# %%
#Q2 find the best stadium winning by wickets

# %%
ipl[ipl['win_by_wickets']>0]['venue'].mode()
# Out:
# 0    Eden Gardens
# dtype: object

# %%
#Q3 for any ipl team which you like which stadium is best when they win the toss

# %%
ipl[ipl['toss_winner']=='Royal Challengers Bangalore']['venue'].mode()
# Out:
# 0    M Chinnaswamy Stadium
# dtype: object

# %%
a=[1,2,3,4,5,6,7,7,7,8,9]

# %%
b=pd.DataFrame(a)

# %%
b.mode()
# Out:
#    0
# 0  7

# %%
#Q4 which is the best chasing team

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl[ipl['win_by_wickets']>0]['winner'].mode()
# Out:
# 0    Kolkata Knight Riders
# dtype: object

# %%
#Q4 which is best defending team

# %%
ipl[ipl['win_by_runs']>0]['winner'].mode()
# Out:
# 0    Mumbai Indians
# dtype: object

# %%
#Q5 find out match winner is also a toss winner

# %%
ipl[ipl['toss_winner']==ipl['winner']].count()[0]
# Out:
# 393

# %%
ipl[ipl['toss_winner']!=ipl['winner']].count()[0]
# Out:
# 363

# %%
672+84
# Out:
# 756

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
team=ipl['toss_winner']==ipl['winner']

# %%
sb.countplot(team)

# %%
#does choosing batting or bowling first help in match winning

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl[ipl['toss_decision']=='bat']['winner'].count()
# Out:
# 292

# %%
ipl[ipl['toss_decision']=='field']['winner'].count()
# Out:
# 460

# %%
hello=ipl.toss_decision[ipl.toss_winner==ipl.winner]

# %%
sb.countplot(hello)

# %%
#Q which team won more by dl method

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl[ipl['dl_applied']==1]['winner'].mode()
# Out:
# 0    Kolkata Knight Riders
# dtype: object

# %%
ipl[ipl['dl_applied']==1]['winner'].count()
# Out:
# 19

# %%
#Q who won man of the match max times playing with csk when result is tie

# %%
cr=ipl['player_of_match']

# %%
a=ipl[ipl['result']=='tie']['player_of_match']

# %%
a
# Out:
# 33       KH Pandya
# 125      YK Pathan
# 189       J Theron
# 387      GH Vihari
# 400        V Kohli
# 475    JP Faulkner
# 535       SE Marsh
# 705         P Shaw
# 746      JJ Bumrah
# Name: player_of_match, dtype: object

# %%
a[ipl['team2']=='Chennai Super Kings']
# Out:
# 189    J Theron
# Name: player_of_match, dtype: object

# %%
# in which city weather affect matches

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
b=ipl[ipl['result']=='no result']['city'].mode()

# %%
b
# Out:
# 0    Bangalore
# dtype: object

# %%
c=ipl[ipl['dl_applied']==1]['city'].mode()

# %%
c
# Out:
# 0    Kolkata
# dtype: object

# %%
plt.figure(figsize=(20,9))
sb.countplot(ipl.city[ipl.dl_applied==1])
plt.show()

# %%
plt.figure(figsize=(20,9))
sb.countplot(ipl.city[ipl.result=='no result'])
plt.show()

# %%
#whch season has more no. of matches

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl['season'].mode()
# Out:
# 0    2013
# dtype: int64

# %%
sb.countplot(data=ipl,x='season')

# %%
#best defending venue

# %%
plt.figure(figsize=(25,18))
sb.swarmplot(x='win_by_runs',y='venue',data=ipl)

# %%
#name the matches done by NJ Llong

# %%
ipl
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5        6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7        8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8        9    2017           Pune  2017-04-11             Delhi Daredevils
# 9       10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10      11    2017        Kolkata  2017-04-13              Kings XI Punjab
# ...

# %%
ipl[ipl['umpire1']=='NJ Llong'][['team1','team2']].count()[0]
# Out:
# 12

# %%
ipl[ipl['umpire2']=='NJ Llong'][['team1','team2']].count()[0]
# Out:
# 13

# %%
ipl[ipl['umpire3']=='NJ Llong'][['team1','team2']].count()[0]
# Out:
# 0
